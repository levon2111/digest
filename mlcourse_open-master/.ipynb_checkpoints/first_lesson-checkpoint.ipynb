# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision=2)

# %%
data = pd.read_csv('./data/beauty.csv', sep=';')

# %%
data.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
data.shape
# Out:
# (1260, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
# wage        1260 non-null float64
# exper       1260 non-null int64
# union       1260 non-null int64
# goodhlth    1260 non-null int64
# black       1260 non-null int64
# female      1260 non-null int64
# married     1260 non-null int64
# service     1260 non-null int64
# educ        1260 non-null int64
# looks       1260 non-null int64
# dtypes: float64(1), int64(9)
# memory usage: 98.5 KB

# %%
data.describe()
# Out:
#               wage        exper        union     goodhlth        black  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      6.306690    18.206349     0.272222     0.933333     0.073810
# std       4.660639    11.963485     0.445280     0.249543     0.261564
# min       1.020000     0.000000     0.000000     0.000000     0.000000
# 25%       3.707500     8.000000     0.000000     1.000000     0.000000
# 50%       5.300000    15.000000     0.000000     1.000000     0.000000
# 75%       7.695000    27.000000     1.000000     1.000000     0.000000
# max      77.720000    48.000000     1.000000     1.000000     1.000000
#
#             female      married      service         educ        looks
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      0.346032     0.691270     0.273810    12.563492     3.185714
# std       0.475892     0.462153     0.446089     2.624489     0.684877
# ...

# %%
type(data['wage'])
# Out:
# pandas.core.series.Series

# %%
data['wage'].head(4)
# Out:
# 0     5.73
# 1     4.28
# 2     7.96
# 3    11.57
# Name: wage, dtype: float64

# %%
data.loc[0:5, ['wage', 'union']]
# Out:
#     wage  union
# 0   5.73      0
# 1   4.28      0
# 2   7.96      0
# 3  11.57      0
# 4  11.42      0
# 5   3.91      0

# %%
data.iloc[:,2:4].head()
# Out:
#    union  goodhlth
# 0      0         1
# 1      0         1
# 2      0         1
# 3      0         1
# 4      0         1

# %%
data[data['female'] == 1]['wage'].mean(), \
data[data['female'] == 0]['wage'].mean()
# Out:
# (4.299357798165137, 7.3688228155339806)

# %%
data[(data['female'] == 0) & (data['married'] == 1)]['wage'].median(), \
data[(data['female'] == 0) & (data['married'] == 0)]['wage'].median()
# Out:
# (6.710000000000001, 5.0649999999999995)

# %%
for look, data_sub in data.groupby('looks'):
    print(look, data_sub['female'].mean())
# Out:
# 1 0.38461538461538464
# 2 0.38028169014084506
# 3 0.32271468144044324
# 4 0.37362637362637363
# 5 0.42105263157894735

# %%
data.groupby('looks')[['wage', 'exper']].agg(np.median)
# Out:
#         wage  exper
# looks
# 1      3.460   32.0
# 2      4.595   18.0
# 3      5.635   18.0
# 4      5.240   12.5
# 5      4.810    8.0

# %%
pd.crosstab(data['married'], data['female'])
# Out:
# female     0    1
# married
# 0        166  223
# 1        658  213

# %%
pd.crosstab(data['female'], data['looks'])
# Out:
# looks   1   2    3    4   5
# female
# 0       8  88  489  228  11
# 1       5  54  233  136   8

# %%
data['wage'].describe()
# Out:
# count    1260.000000
# mean        6.306690
# std         4.660639
# min         1.020000
# 25%         3.707500
# 50%         5.300000
# 75%         7.695000
# max        77.720000
# Name: wage, dtype: float64

# %%
data['is_reach'] =( data['wage'] > data['wage'].quantile(0.75)).astype('int64')

# %%
data.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0   5.73     30      0         1      0       1        1        1    14
# 1   4.28     28      0         1      0       1        1        0    12
# 2   7.96     35      0         1      0       1        0        0    10
# 3  11.57     38      0         1      0       0        1        1    16
# 4  11.42     27      0         1      0       0        1        0    16
#
#    looks  is_reach
# 0      4         0
# 1      3         0
# 2      4         1
# 3      3         1
# 4      3         1

# %%
data['rubbish'] = .56*data['wage']+ .32 * data['exper']

# %%
data.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0   5.73     30      0         1      0       1        1        1    14
# 1   4.28     28      0         1      0       1        1        0    12
# 2   7.96     35      0         1      0       1        0        0    10
# 3  11.57     38      0         1      0       0        1        1    16
# 4  11.42     27      0         1      0       0        1        0    16
#
#    looks  is_reach  rubbish
# 0      4         0  12.8088
# 1      3         0  11.3568
# 2      4         1  15.6576
# 3      3         1  18.6392
# 4      3         1  15.0352

# %%
data['gender'] = data['female'].apply(lambda x: 'male' if x == 1 else 'female')

# %%
data.head(15)
# Out:
#      wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0    5.73     30      0         1      0       1        1        1    14
# 1    4.28     28      0         1      0       1        1        0    12
# 2    7.96     35      0         1      0       1        0        0    10
# 3   11.57     38      0         1      0       0        1        1    16
# 4   11.42     27      0         1      0       0        1        0    16
# 5    3.91     20      0         0      0       1        1        0    12
# 6    8.76     12      0         1      0       0        1        0    16
# 7    7.69      5      1         1      0       0        0        0    16
# 8    5.00      5      0         1      0       1        0        0    16
# 9    3.89     12      0         1      0       1        0        0    12
# 10   3.45      3      0         1      0       1        0        0    12
# 11   4.03      6      0         1      0       0        1        0    16
# ...

# %%
    d = {1: 'union', 0: 'none-union'}

# %%
data['union'] = data['union'].map(d).head(2)

# %%
data.head()
# Out:
#     wage  exper       union  goodhlth  black  female  married  service  educ  \
# 0   5.73     30  none-union         1      0       1        1        1    14
# 1   4.28     28  none-union         1      0       1        1        0    12
# 2   7.96     35         NaN         1      0       1        0        0    10
# 3  11.57     38         NaN         1      0       0        1        1    16
# 4  11.42     27         NaN         1      0       0        1        0    16
#
#    looks  is_reach  rubbish  gender
# 0      4         0  12.8088    male
# 1      3         0  11.3568    male
# 2      4         1  15.6576    male
# 3      3         1  18.6392  female
# 4      3         1  15.0352  female

# %%
data
# Out:
#        wage  exper       union  goodhlth  black  female  married  service  \
# 0      5.73     30  none-union         1      0       1        1        1
# 1      4.28     28  none-union         1      0       1        1        0
# 2      7.96     35         NaN         1      0       1        0        0
# 3     11.57     38         NaN         1      0       0        1        1
# 4     11.42     27         NaN         1      0       0        1        0
# 5      3.91     20         NaN         0      0       1        1        0
# 6      8.76     12         NaN         1      0       0        1        0
# 7      7.69      5         NaN         1      0       0        0        0
# 8      5.00      5         NaN         1      0       1        0        0
# 9      3.89     12         NaN         1      0       1        0        0
# 10     3.45      3         NaN         1      0       1        0        0
# 11     4.03      6         NaN         1      0       0        1        0
# ...
